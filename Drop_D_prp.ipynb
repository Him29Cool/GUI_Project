# %%
from tkinter import *  
top = Tk()  
top.geometry("450x350") 

def selection():  
    selection = "Chosen Option    " + str(radio.get())  
    label.config(text = selection)
lbl = Label(text = "PACKAGE RETURN FORM",fg="black")  
lbl.place(x=380,y=0)
var = StringVar(top)
var.set("DELIVER TO APPLICANT ABOVE(METRO AREA")     # initial value

option = OptionMenu(top, var, "1.DELIVER TO APPLICANT ABOVE(METRO AREA", "2.DELIVER TO OTHER RECIPIENT/ADDRESS (METRO AREA)", 
                    "3.POST TO APPLICANT ABOVE(WITHIN AUSTRALIA)", "4.POST TO OTHER RECIPIENT/ADDRESS (WITHIN AUSTRALIA)",
                    "5.POST TO APPLICANT ABOVE(INTERNATIONAL)","6.POST TO OTHER RECIPIENT/ADDRESS (INTERNATIONAL)",
                   "7.DELIVER TO POST OFFICE ABOVE","8.DELIVER TO OTHER BRANCH OF POST OFFICE: ______________")
option.place(x=50,y=25)

def ok():
    print("value is", var.get())
name = Label(top,text = "Name")
name.place(x=50,y=60) 
Lastname = Label(top,text = "Address")
Lastname.place(x=300,y=60)
 
e1 = Entry(top).place(x=100,y=60)
e3 = Entry(top).place(x=350,y=60)
email = Label(top, text = "Email").place(x = 50, y = 90)  
password = Label(top, text = "Phone Number").place(x = 255, y = 90)  
  
e1 = Entry(top).place(x = 100, y = 90)  
e2 = Entry(top).place(x = 350, y = 90)
lbl = Label(top, text="SPLIT PACKAGE FOR DELIVERY")
lbl.place(x=50,y=120)
lbl = Label(top, text="DECLARATION BY APPLICANT: I, THE ABOVE NAMED APPLICANT,")
lbl.place(x=255,y=120)
lbl = Label(top, text="AUTHORISE THE DELIVERY OF THE RETURN OF THE PACKAGE AS PER MY INSTRUCTIONS HEREWITH.")
lbl.place(x=255,y=140)
name = Label(top,text = "SIGNATURE  _______________")
name.place(x=255,y=170) 
Lastname = Label(top,text = "DATE    ____________")
Lastname.place(x=255,y=200)
lbl = Label(top, text="Divide package into")
lbl.place(x=50,y=170)
radio = StringVar()
Radiobutton(top, text='2', variable=radio, value=2).place(x=50,y=190) 
Radiobutton(top, text='3', variable=radio, value=3).place(x=80,y=190)
Radiobutton(top, text='4', variable=radio, value=4).place(x=110,y=190)
Radiobutton(top, text='Fast Delivery', variable=radio, value=5).place(x=50,y=220) 
Radiobutton(top, text='Free Delivery', variable=radio, value=6).place(x=50,y=250)

b2 = Button(top, text="SAVE",
             command=selection)
b2.place(x=275,y=250)
frame1=Frame(top, width=1000,highlightbackground="gray",highlightthickness=3)
frame1.place(x=0,y=0)
frame1=Frame(top, width=1000,highlightbackground="gray",highlightthickness=3)
frame1.place(x=0,y=320)
radio.set('Fast Delivery')   
label = Label(top)  
label.grid(row=24, column=5) 
top.mainloop()
