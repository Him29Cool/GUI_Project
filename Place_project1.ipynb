# %%
from tkinter import *  
top = Tk()  
top.geometry("450x350") 

def selection():  
    selection = "Chosen Option    " + str(radio.get())  
    label.config(text = selection)
lbl = Label(text = "PACKAGE RETURN FORM",fg="black")  
lbl.place(x=380,y=0)

radio = StringVar()  
R1 = Radiobutton(top, text=" DELIVER TO APPLICANT ABOVE(METRO AREA)", variable=radio, value=" DELIVER TO APPLICANT ABOVE(METRO AREA)",  
                      command=selection )  
R1.place(x=50,y=20)  
      
R2 = Radiobutton(top, text="DELIVER TO OTHER RECIPIENT/ADDRESS (METRO AREA)", variable=radio, value="DELIVER TO OTHER RECIPIENT/ADDRESS (METRO AREA)",  
                      command=selection )  
R2.place(x=375,y=20)
name = Label(top,text = "Name")
name.place(x=375,y=40) 
Lastname = Label(top,text = "Address")
Lastname.place(x=375,y=65)
 
e1 = Entry(top).place(x=420,y=40)
e3 = Entry(top).place(x=420,y=65)
# email = Label(top, text = "Email").place(x = 375, y = 90)  
# password = Label(top, text = "Phone Number").place(x = 375, y = 120)  
# e1 = Entry(top).place(x = 420, y = 33)  
# e2 = Entry(top).place(x = 420, y = 330)
 
R3 = Radiobutton(top, text=" POST TO APPLICANT ABOVE(WITHIN AUSTRALIA)", variable=radio, value=" POST TO APPLICANT ABOVE(WITHIN AUSTRALIA)",
                   command=selection)
R3.place(x=50,y=90) 

R4 = Radiobutton(top, text="POST TO OTHER RECIPIENT/ADDRESS (WITHIN AUSTRALIA)", variable=radio, value="POST TO OTHER RECIPIENT/ADDRESS (WITHIN AUSTRALIA)",  
                     command=selection )  
R4.place(x=375,y=90)
name = Label(top,text = "Name")
name.place(x=375,y=110)
Lastname = Label(top,text = "Address")
Lastname.place(x=375,y=130)
e1 = Entry(top).place(x=420,y=110) 
e3 = Entry(top).place(x=420,y=130)

R5 = Radiobutton(top, text="POST TO APPLICANT ABOVE(INTERNATIONAL)", variable=radio, value="POST TO APPLICANT ABOVE(INTERNATIONAL)",  
                     command=selection )  
R5.place(x=50,y=150)

R6 = Radiobutton(top, text="POST TO OTHER RECIPIENT/ADDRESS (INTERNATIONAL)", variable=radio, value="POST TO OTHER RECIPIENT/ADDRESS (INTERNATIONAL)",  
                       command=selection)  
R6.place(x=375,y=150)
name = Label(top,text = "Name")
name.place(x=375,y=170)
Lastname = Label(top,text = "Address")
Lastname.place(x=375,y=190)
e1 = Entry(top).place(x=420,y=170)
e3 = Entry(top).place(x=420,y=190)

R7 = Radiobutton(top, text="DELIVER TO POST OFFICE ABOVE", variable=radio, value="DELIVER TO POST OFFICE ABOVE",  
                       command=selection) 
R7.place(x=50,y=210)
R8 = Radiobutton(top, text=" DELIVER TO OTHER BRANCH OF POST OFFICE: ______________", variable=radio, value=" DELIVER TO OTHER BRANCH OF POST OFFICE: ______________",  
                       command=selection)
R8.place(x=375,y=210)
lbl = Label(top, text="SPLIT PACKAGE FOR DELIVERY")
lbl.place(x=50,y=250)
lbl = Label(top, text="DECLARATION BY APPLICANT: I, THE ABOVE NAMED APPLICANT,")
lbl.place(x=375,y=250)
lbl = Label(top, text="AUTHORISE THE DELIVERY OF THE RETURN OF THE PACKAGE AS PER MY INSTRUCTIONS HEREWITH.")
lbl.place(x=375,y=270)
name = Label(top,text = "SIGNATURE  _______________")
name.place(x=375,y=290) 
Lastname = Label(top,text = "DATE    ____________")
Lastname.place(x=375,y=310)
lbl = Label(top, text="Divide package into")
lbl.place(x=50,y=270)
 
Radiobutton(top, text='2', variable=radio, value=2).place(x=50,y=290) 
Radiobutton(top, text='3', variable=radio, value=3).place(x=80,y=290)
Radiobutton(top, text='4', variable=radio, value=4).place(x=110,y=290)
email = Label(top, text = "Email").place(x = 50, y = 330)  
password = Label(top, text = "Phone Number").place(x = 375, y = 330)  
  
e1 = Entry(top).place(x = 100, y = 330)  
e2 = Entry(top).place(x = 470, y = 330)  
  
Radiobutton(top, text='Fast Delivery', variable=radio, value=2).place(x=50,y=380) 
Radiobutton(top, text='Free Delivery', variable=radio, value=3).place(x=50,y=420)

  
b2 = Button(top, text="SAVE",
             command=selection)
b2.place(x=375,y=420)
# lbl = Label(top, text="SECTION-B")
# lbl.place(x=0,y=170)

frame1=Frame(top, width=1000,highlightbackground="gray",highlightthickness=3)
frame1.place(x=0,y=0)
frame1=Frame(top, width=1000,highlightbackground="gray",highlightthickness=3)
frame1.place(x=0,y=450)
radio.set('SPLIT PACKAGE FOR DELIVERY')   
label = Label(top)  
label.grid(row=24, column=5) 

top.mainloop()
